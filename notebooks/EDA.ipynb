# %%
#%pip install pandas geopandas pyarrow fiona matplotlib seaborn shapely descartes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 24.2 is available.
# You should consider upgrading via the 'd:\braulio otavalo\learning\gis & geoai\cesium-project\notebooks\jupyter\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the GeoParquet file with flood risk data
gdf = gpd.read_parquet('D:\Braulio Otavalo\Learning\GIS & GeoAI\Cesium-project\data\Ecuador_flood_risk.parquet')

# %%
# Información básica del GeoDataFrame
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cartodb_id  2 non-null      int32
#  1   name        2 non-null      object
#  2   geometry    2 non-null      geometry
# dtypes: geometry(1), int32(1), object(1)
# memory usage: 168.0+ bytes

# %%
# Mostrar las primeras filas del GeoDataFrame
gdf.head()
# Out:
#    cartodb_id   name                                           geometry
# 0           2  MEDIA  MULTIPOLYGON Z (((-80.77512 -2.37932 0, -80.77...
# 1           3   ALTA  MULTIPOLYGON Z (((-80.57921 -2.4316 0, -80.579...

# %%
# Resumen estadístico
gdf.describe()
# Out:
#        cartodb_id
# count    2.000000
# mean     2.500000
# std      0.707107
# min      2.000000
# 25%      2.250000
# 50%      2.500000
# 75%      2.750000
# max      3.000000

# %%
# Visualización de un histograma de una columna específica
gdf.plot()
sns.histplot(gdf['name'])
plt.show()

# %%
# Mapear un atributo específico
gdf.plot(column='name', legend=True)
plt.show()

# %%
# Print unique geometry types
print(gdf['geometry'].geom_type.unique())
# Out:
# ['MultiPolygon']
